-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS databricks_course_ext_dl_formula1
URL "abfss://formula1@databrickscourseextdl997.dfs.core.windows.net/"
WITH (STORAGE CREDENTIAL `databricks-course-sc`)
COMMENT 'Creating External Location for formula1 container'

-- %%
%fs ls "abfss://formula1@databrickscourseextdl997.dfs.core.windows.net/"

-- %%
CREATE CATALOG IF NOT EXISTS formula1
   MANAGED LOCATION 'abfss://formula1@databrickscourseextdl997.dfs.core.windows.net/' 
   COMMENT 'This is the main catalog for the formula1 project' ;

-- %%
CREATE SCHEMA IF NOT EXISTS formula1.landing;
CREATE SCHEMA IF NOT EXISTS formula1.bronze
    MANAGED LOCATION 'abfss://formula1@databrickscourseextdl997.dfs.core.windows.net/bronze';
CREATE SCHEMA IF NOT EXISTS formula1.silver
    MANAGED LOCATION 'abfss://formula1@databrickscourseextdl997.dfs.core.windows.net/silver';
CREATE SCHEMA IF NOT EXISTS formula1.gold
    MANAGED LOCATION 'abfss://formula1@databrickscourseextdl997.dfs.core.windows.net/gold';

-- %%
CREATE EXTERNAL VOLUME formula1.landing.files
LOCATION 'abfss://formula1@databrickscourseextdl997.dfs.core.windows.net/landing';

-- %%
%fs ls '/Volumes/formula1/landing/files'
